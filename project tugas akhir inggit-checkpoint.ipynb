# %% [markdown]
# Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import os
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score

# %% [markdown]
# membaca file excel ke dalam Pandas DataFrame

# %%
df = pd.read_excel('Kemiskinan di pulau jawa missing.xlsx')
df
# Out:
#     Kabupaten/Kota  Jumlah penduduk miskin (000)  Presentase penduduk miskin  \
# 0            Bogor                        474.74                        7.73
# 1         Sukabumi                        186.28                        7.34
# 2          Cianjur                        246.81                       10.55
# 3          Bandung                        258.61                        6.80
# 4            Garut                        276.67                       10.42
# ..             ...                           ...                         ...
# 95   Kota Pasuruan                         13.02                        6.37
# 96  Kota Mojokerto                          7.88                        5.98
# 97     Kota Madiun                          8.49                        4.76
# 98   Kota Surabaya                        138.21                        4.27
# 99       Kota Batu                          8.05                        3.79
#
#       P1    P2  Garis kemiskinan (Rp/Kap/Bulan)
# 0   1.49  0.45                         443787.0
# 1   0.93  0.19                         357636.0
# 2   1.35  0.27                         406829.0
# 3   0.90  0.21                         398884.0
# 4   1.81  0.45                         335134.0
# ..   ...   ...                              ...
# 95  0.93  0.22                         486893.0
# 96  0.87  0.18                         531804.0
# 97  0.40  0.06                         551620.0
# 98  0.69  0.18                         652540.0
# 99  0.64  0.16                         564010.0
#
# [100 rows x 6 columns]

# %% [markdown]
# menampilkan 5 baris pertama dataframe

# %%
df.head()
# Out:
#   Kabupaten/Kota  Jumlah penduduk miskin (000)  Presentase penduduk miskin  \
# 0          Bogor                        474.74                        7.73
# 1       Sukabumi                        186.28                        7.34
# 2        Cianjur                        246.81                       10.55
# 3        Bandung                        258.61                        6.80
# 4          Garut                        276.67                       10.42
#
#      P1    P2  Garis kemiskinan (Rp/Kap/Bulan)
# 0  1.49  0.45                         443787.0
# 1  0.93  0.19                         357636.0
# 2  1.35  0.27                         406829.0
# 3  0.90  0.21                         398884.0
# 4  1.81  0.45                         335134.0

# %% [markdown]
# menampilkan info data

# %% [markdown]
# melihat jumlah baris dan kolom di DataFrame

# %%
df_shape = df.shape
print("Number of rows:", df_shape[0])
print("Number of columns:", df_shape[1])
# Out:
# Number of rows: 100
# Number of columns: 6

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# informasi ringkasan tentang DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Kabupaten/Kota                   100 non-null    object
#  1   Jumlah penduduk miskin (000)     100 non-null    float64
#  2   Presentase penduduk miskin       99 non-null     float64
#  3   P1                               100 non-null    float64
#  4   P2                               99 non-null     float64
#  5   Garis kemiskinan (Rp/Kap/Bulan)  99 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# Ringkasan informasi statistik untuk setiap kolom numerik di DataFrame

# %%
df.describe().transpose()
# Out:
#                                  count           mean           std  \
# Jumlah penduduk miskin (000)     100.0     120.837300     78.062418
# Presentase penduduk miskin        99.0      10.009495      3.629716
# P1                               100.0       1.484400      0.664891
# P2                                99.0       0.349192      0.198359
# Garis kemiskinan (Rp/Kap/Bulan)   99.0  451347.898990  84780.918670
#
#                                        min          25%         50%  \
# Jumlah penduduk miskin (000)          7.88      73.8125     112.325
# Presentase penduduk miskin            2.53       7.3900       9.710
# P1                                    0.40       1.0150       1.345
# P2                                    0.06       0.2200       0.300
# Garis kemiskinan (Rp/Kap/Bulan)  327758.00  391183.0000  433864.000
#
#                                          75%        max
# Jumlah penduduk miskin (000)        157.3050     474.74
# Presentase penduduk miskin           12.0500      21.61
# P1                                    1.7625       3.72
# P2                                    0.4150       1.16
# Garis kemiskinan (Rp/Kap/Bulan)  499258.0000  744771.00

# %% [markdown]
# cek nilai fitur yang hilang

# %%
print("\nJumlah nilai yang hilang:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang:
# Kabupaten/Kota                     0
# Jumlah penduduk miskin (000)       0
# Presentase penduduk miskin         1
# P1                                 0
# P2                                 1
# Garis kemiskinan (Rp/Kap/Bulan)    1
# dtype: int64

# %% [markdown]
# Fungsi untuk mengisi data yang hilang dengan rata-rata

# %%
def isi_data_hilang_dengan_rata_rata(df):
    for kolom in df.columns:
        if pd.api.types.is_numeric_dtype(df[kolom].dtype):  # Cek tipe data kolom
            rata_rata = df[kolom].mean()
            df[kolom].fillna(rata_rata, inplace=True)

# %% [markdown]
# Memanggil fungsi untuk mengisi data yang hilang dengan rata-rata

# %%
isi_data_hilang_dengan_rata_rata(df)

# %% [markdown]
# Menampilkan DataFrame yang telah diisi

# %%
print(df)
# Out:
#     Kabupaten/Kota  Jumlah penduduk miskin (000)  Presentase penduduk miskin  \
# 0            Bogor                        474.74                        7.73
# 1         Sukabumi                        186.28                        7.34
# 2          Cianjur                        246.81                       10.55
# 3          Bandung                        258.61                        6.80
# 4            Garut                        276.67                       10.42
# ..             ...                           ...                         ...
# 95   Kota Pasuruan                         13.02                        6.37
# 96  Kota Mojokerto                          7.88                        5.98
# 97     Kota Madiun                          8.49                        4.76
# 98   Kota Surabaya                        138.21                        4.27
# 99       Kota Batu                          8.05                        3.79
#
#       P1    P2  Garis kemiskinan (Rp/Kap/Bulan)
# 0   1.49  0.45                         443787.0
# 1   0.93  0.19                         357636.0
# 2   1.35  0.27                         406829.0
# 3   0.90  0.21                         398884.0
# 4   1.81  0.45                         335134.0
# ..   ...   ...                              ...
# 95  0.93  0.22                         486893.0
# 96  0.87  0.18                         531804.0
# 97  0.40  0.06                         551620.0
# 98  0.69  0.18                         652540.0
# 99  0.64  0.16                         564010.0
#
# [100 rows x 6 columns]

# %% [markdown]
# Mencetak hasil dari mengisi data yang hilang dengan rata-rata

# %%
print("\nJumlah nilai yang hilang:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang:
# Kabupaten/Kota                     0
# Jumlah penduduk miskin (000)       0
# Presentase penduduk miskin         0
# P1                                 0
# P2                                 0
# Garis kemiskinan (Rp/Kap/Bulan)    0
# dtype: int64

# %% [markdown]
# # Rekayasa Fitur untuk Tingkat Kemiskinan di Pulau Jawa

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Korelasi antara Fitur Numerik')
plt.show()

# %% [markdown]
#  Membuat Visualisasi Distribusi Penduduk Miskin per Kabupaten/Kota

# %%
plt.figure(figsize=(15, 8))
plt.bar(df['Kabupaten/Kota'], df['Jumlah penduduk miskin (000)'])
plt.xticks(rotation=90)
plt.xlabel('Kabupaten/Kota')
plt.ylabel('Jumlah Penduduk Miskin (ribu)')
plt.title('Distribusi Penduduk Miskin per Kabupaten/Kota')
plt.tight_layout()
plt.show()

# %% [markdown]
# Membuat Visualisasi Perbandingan Presentase Penduduk Miskin Dan Garis Kemiskinan per Kabupaten/Kota

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['Kabupaten/Kota'], df['Presentase penduduk miskin'], marker='o', label='Presentase Penduduk Miskin')
plt.plot(df['Kabupaten/Kota'], df['Garis kemiskinan (Rp/Kap/Bulan)'], marker='o', label='Garis Kemiskinan')
plt.xticks(rotation=90)
plt.xlabel('Kabupaten/Kota')
plt.ylabel('Presentase / Garis Kemiskinan')
plt.title('Perbandingan Presentase Penduduk Miskin dan Garis Kemiskinan per Kabupaten/Kota')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Membuat Visualisasi Korelasi antara Presentase penduduk Miskin dan Garis Kemiskinan

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Presentase penduduk miskin', y='Garis kemiskinan (Rp/Kap/Bulan)')
plt.xlabel('Presentase Penduduk Miskin')
plt.ylabel('Garis Kemiskinan (Rp/Kap/Bulan)')
plt.title('Korelasi antara Presentase Penduduk Miskin dan Garis Kemiskinan')
plt.show()

# %% [markdown]
# Menghitung nilai rata-rata (mean) dari tiga kolom dalam DataFrame

# %%
mean_miskin = df['Jumlah penduduk miskin (000)'].mean()
mean_presentase = df['Presentase penduduk miskin'].mean()
mean_garis = df['Garis kemiskinan (Rp/Kap/Bulan)'].mean()

# %% [markdown]
# Menampilkan nilai rata-rata (mean) dari tiga kolom dalam DataFrame

# %%
print("Mean Jumlah Penduduk Miskin:", mean_miskin)
print("Mean Presentase Penduduk Miskin:", mean_presentase)
print("Mean Garis Kemiskinan:", mean_garis)
# Out:
# Mean Jumlah Penduduk Miskin: 120.83729999999994
# Mean Presentase Penduduk Miskin: 10.009494949494947
# Mean Garis Kemiskinan: 451347.898989899

# %% [markdown]
# Menghitung nilai tengah (median) dari tiga kolom dalam DataFrame

# %%
median_miskin = df['Jumlah penduduk miskin (000)'].median()
median_presentase = df['Presentase penduduk miskin'].median()
median_garis = df['Garis kemiskinan (Rp/Kap/Bulan)'].median()

# %% [markdown]
# Menampilkan nilai tengah (median) dari tiga kolom dalam DataFrame

# %%
print("Median Jumlah Penduduk Miskin:", median_miskin)
print("Median Presentase Penduduk Miskin:", median_presentase)
print("Median Garis Kemiskinan:", median_garis)
# Out:
# Median Jumlah Penduduk Miskin: 112.325
# Median Presentase Penduduk Miskin: 9.73
# Median Garis Kemiskinan: 434091.0

# %% [markdown]
# Menghitung nilai yang paling banyak muncul(Modus) dari tiga kolom dalam DataFrame

# %%
modus_miskin = df['Jumlah penduduk miskin (000)'].mode()
modus_presentase = df['Presentase penduduk miskin'].mode()
modus_garis = df['Garis kemiskinan (Rp/Kap/Bulan)'].mode()

# %% [markdown]
# Menampilkan nilai yang paling banyak muncul(Modus) dari tiga kolom dalam DataFrame

# %%
print("Modus Jumlah Penduduk Miskin:", modus_miskin[0])
print("Modus Presentase Penduduk Miskin:", modus_presentase[0])
print("Modus Garis Kemiskinan:", modus_garis[0])
# Out:
# Modus Jumlah Penduduk Miskin: 145.33
# Modus Presentase Penduduk Miskin: 4.25
# Modus Garis Kemiskinan: 371665.0

# %% [markdown]
# Mengurutkan DataFrame df berdasarkan nilai dalam kolom 'Jumlah penduduk miskin (000)' secara menurun (descending order)

# %%
df_sorted = df.sort_values(by='Jumlah penduduk miskin (000)', ascending=False)

# %% [markdown]
#  Mengambil baris yang memiliki nilai tertinggi dalam kolom 'Jumlah penduduk miskin (000)' setelah DataFrame tersebut diurutkan

# %%
highest_poverty = df_sorted.iloc[0]

# %% [markdown]
# Mengambil baris yang memiliki nilai terendah dalam kolom 'Jumlah penduduk miskin (000)' setelah DataFrame tersebut diurutkan

# %%
lowest_poverty = df_sorted.iloc[-1]

# %% [markdown]
# Menampilkan Kota/Kabupaten dengan Tingkat Kemiskinan Tertinggi

# %%
print("Kota/Kabupaten dengan Tingkat Kemiskinan Tertinggi:")
print(highest_poverty)
# Out:
# Kota/Kabupaten dengan Tingkat Kemiskinan Tertinggi:
# Kabupaten/Kota                        Bogor
# Jumlah penduduk miskin (000)         474.74
# Presentase penduduk miskin             7.73
# P1                                     1.49
# P2                                     0.45
# Garis kemiskinan (Rp/Kap/Bulan)    443787.0
# Name: 0, dtype: object

# %% [markdown]
#  Menampilkan Kota/Kabupaten dengan Tingkat Kemiskinan Terendah

# %%
print("\nKota/Kabupaten dengan Tingkat Kemiskinan Terendah:")
print(lowest_poverty)
# Out:
# Kota/Kabupaten dengan Tingkat Kemiskinan Terendah:
# Kabupaten/Kota                     Kota Mojokerto
# Jumlah penduduk miskin (000)                 7.88
# Presentase penduduk miskin                   5.98
# P1                                           0.87
# P2                                           0.18
# Garis kemiskinan (Rp/Kap/Bulan)          531804.0
# Name: 96, dtype: object

# %% [markdown]
# Mengganti karakter koma (,) dengan titik (.) dalam kolom-kolom numerik dalam DataFrame df dan mengubah kolom-kolom tersebut

# %%
df.replace({',': '.'}, regex=True, inplace=True)
numeric_columns = df.columns[1:]  # Kolom numerik kecuali 'Kabupaten/Kota'
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)

# %% [markdown]
# Menghapus baris (row) yang mengandung setidaknya satu nilai yang hilang (NaN, Not-a-Number) dari DataFrame

# %%
df.dropna(inplace=True)

# %% [markdown]
# Mengambil subset dari DataFrame df yang hanya terdiri dari kolom-kolom numerik

# %%
X = df[numeric_columns]

# %% [markdown]
# Mengisi nilai NaN dengan nilai median untuk kolom tertentu

# %%
columns_to_fill = ['Jumlah penduduk miskin (000)', 'Presentase penduduk miskin']
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].median())

# %% [markdown]
# # Metode Elbow untuk Tingkat Kemiskinan di Pulau Jawa

# %% [markdown]
#  mengambil nilai dari kolom 'Jumlah penduduk miskin' (000)

# %%
X = df[['Presentase penduduk miskin']].values

# %% [markdown]
# membuat sebuah list (daftar) dengan nama wcss

# %%
wcss = []

# %% [markdown]
#  menghitung nilai Within-Cluster Sum of Squares (WCSS) untuk berbagai jumlah cluster (dari 1 hingga 10).

# %%
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Inggit\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# membuat sebuah grafik yang menampilkan hasil dari metode elbow (siku) dalam menentukan jumlah cluster yang optimal dalam menentukan jumlah cluster

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='-', color='b')
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluster')
plt.ylabel('WCSS (Within-cluster sum of squares)')
plt.grid(True)
plt.show()

# %% [markdown]
#  Mengambil subset dari DataFrame df yang terdiri dari kolom-kolom numerik dan menyimpannya dalam variabel X

# %%
X = df[numeric_columns]

# %% [markdown]
#  Melakukan penskalaan (scaling) data dalam variabel X menggunakan teknik StandardScaler dari pustaka scikit-learn (sklearn)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# pengaturan nilai yang menentukan jumlah kluster yang akan digunakan dalam algoritma K-Means

# %%
n_clusters = 3

# %% [markdown]
# Membuat objek SimpleImputer untuk menggantikan NaN dengan mean

# %%
imputer = SimpleImputer(strategy='mean')

# %% [markdown]
# Mengisi nilai-nilai NaN dalam dataset dengan mean

# %%
X_imputed = imputer.fit_transform(X)

# %% [markdown]
# # Algortima Machine Learning Untuk pengelompokan Kemiskinan di Pulau Jawa

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_imputed)

# %% [markdown]
# mencetak atau menampilkan dua kolom dari DataFrame df, yaitu 'Kabupaten/Kota' dan 'Cluster'

# %%
print(df[['Kabupaten/Kota', 'Cluster']])
# Out:
#     Kabupaten/Kota  Cluster
# 0            Bogor        2
# 1         Sukabumi        0
# 2          Cianjur        0
# 3          Bandung        0
# 4            Garut        0
# ..             ...      ...
# 95   Kota Pasuruan        2
# 96  Kota Mojokerto        1
# 97     Kota Madiun        1
# 98   Kota Surabaya        1
# 99       Kota Batu        1
#
# [100 rows x 2 columns]

# %% [markdown]
# Menampilkan semua baris

# %%
print(df[['Kabupaten/Kota', 'Cluster']])
import pandas as pd
pd.set_option('display.max_rows', None)  # Menampilkan semua baris

print(df)
# Out:
#       Kabupaten/Kota  Cluster
# 0              Bogor        2
# 1           Sukabumi        0
# 2            Cianjur        0
# 3            Bandung        0
# 4              Garut        0
# 5        Tasikmalaya        0
# 6             Ciamis        2
# 7           Kuningan        0
# 8            Cirebon        0
# 9         Majalengka        2
# 10          Sumedang        0
# 11         Indramayu        2
# 12            Subang        0
# 13        Purwakarta        0
# 14          Karawang        1
# 15            Bekasi        1
# 16     Bandung Barat        0
# 17       Pangandaran        0
# 18        Kota Bogor        1
# 19     Kota Sukabumi        1
# 20      Kota Bandung        1
# 21      Kota Cirebon        2
# 22       Kota Bekasi        1
# 23        Kota Depok        1
# 24       Kota Cimahi        1
# 25  Kota Tasikmalaya        2
# 26       Kota Banjar        0
# 27           Cilacap        0
# 28          Banyumas        2
# 29       Purbalingga        0
# 30     Banjar negara        0
# 31           Kebumen        0
# 32         Purworejo        0
# 33          Wonosobo        0
# 34          Magelang        0
# 35          Boyolali        0
# 36            Klaten        2
# 37         Sukoharjo        2
# 38          Wonogiri        0
# 39       Karanganyar        2
# 40            Sragen        0
# 41          Grobogan        2
# 42             Blora        0
# 43           Rembang        2
# 44              Pati        2
# 45             Kudus        2
# 46            Jepara        2
# 47             Demak        2
# 48          Semarang        2
# 49        Temanggung        0
# 50            Kendal        2
# 51            Batang        0
# 52        Pekalongan        2
# 53          Pemalang        2
# 54             Tegal        2
# 55            Brebes        2
# 56     Kota Magelang        1
# 57    Kota Surakarta        1
# 58     Kota Salatiga        1
# 59     Kota Semarang        1
# 60   Kota Pekalongan        2
# 61        Kota Tegal        1
# 62           Pacitan        0
# 63          Ponorogo        0
# 64        Trenggalek        0
# 65       Tulungagung        0
# 66            Blitar        0
# 67            Kediri        0
# 68            Malang        0
# 69          Lumajang        0
# 70            Jember        0
# 71        Banyuwangi        0
# 72         Bondowoso        2
# 73         Situbondo        0
# 74       Probolinggo        2
# 75          Pasuruan        0
# 76          Sidoarjo        1
# 77         Mojokerto        2
# 78           Jombang        2
# 79           Nganjuk        2
# 80            Madiun        0
# 81           Magetan        0
# 82             Ngawi        0
# 83        Bojonegoro        0
# 84             Tuban        2
# 85          Lamongan        2
# 86            Gresik        1
# 87         Bangkalan        2
# 88           Sampang        0
# 89         Pamekasan        0
# 90           Sumenep        2
# 91       kota Kediri        1
# 92       Kota Blitar        1
# 93       Kota Malang        1
# 94  Kota Probolinggo        1
# 95     Kota Pasuruan        2
# 96    Kota Mojokerto        1
# 97       Kota Madiun        1
# 98     Kota Surabaya        1
# 99         Kota Batu        1
#       Kabupaten/Kota  Jumlah penduduk miskin (000)  \
# 0              Bogor                        474.74
# 1           Sukabumi                        186.28
# 2            Cianjur                        246.81
# 3            Bandung                        258.61
# 4              Garut                        276.67
# 5        Tasikmalaya                        194.10
# 6             Ciamis                         93.96
# 7           Kuningan                        140.25
# 8            Cirebon                        266.10
# 9         Majalengka                        147.12
# 10          Sumedang                        120.12
# 11         Indramayu                        225.04
# 12            Subang                        155.34
# 13        Purwakarta                         83.44
# 14          Karawang                        199.91
# 15            Bekasi                        201.14
# 16     Bandung Barat                        183.67
# 17       Pangandaran                         37.91
# 18        Kota Bogor                         79.15
# 19     Kota Sukabumi                         26.59
# 20      Kota Bandung                        109.82
# 21      Kota Cirebon                         31.47
# 22       Kota Bekasi                        137.39
# 23        Kota Depok                         64.36
# 24       Kota Cimahi                         31.16
# 25  Kota Tasikmalaya                         87.13
# 26       Kota Banjar                         12.73
# 27           Cilacap                        190.96
# 28          Banyumas                        220.47
# 29       Purbalingga                        145.33
# 30     Banjar negara                        141.25
# 31           Kebumen                        196.16
# 32         Purworejo                         82.64
# 33          Wonosobo                        128.11
# 34          Magelang                        145.33
# 35          Boyolali                         97.18
# 36            Klaten                        144.87
# 37         Sukoharjo                         68.72
# 38          Wonogiri                        105.19
# 39       Karanganyar                         88.56
# 40            Sragen                        115.14
# 41          Grobogan                        163.20
# 42             Blora                         99.83
# 43           Rembang                         94.56
# 44              Pati                        118.04
# 45             Kudus                         66.06
# 46            Jepara                         89.08
# 47             Demak                        143.01
# 48          Semarang                         78.60
# 49        Temanggung                         73.04
# 50            Kendal                         93.03
# 51            Batang                         69.94
# 52        Pekalongan                         87.53
# 53          Pemalang                        195.84
# 54             Tegal                        113.62
# 55            Brebes                        290.66
# 56     Kota Magelang                          8.65
# 57    Kota Surakarta                         45.94
# 58     Kota Salatiga                          9.45
# 59     Kota Semarang                         79.87
# 60   Kota Pekalongan                         21.81
# 61        Kota Tegal                         19.78
# 62           Pacitan                         76.93
# 63          Ponorogo                         81.80
# 64        Trenggalek                         76.75
# 65       Tulungagung                         70.52
# 66            Blitar                        101.94
# 67            Kediri                        169.46
# 68            Malang                        252.88
# 69          Lumajang                         95.04
# 70            Jember                        232.73
# 71        Banyuwangi                        122.01
# 72         Bondowoso                        105.69
# 73         Situbondo                         81.46
# 74       Probolinggo                        203.23
# 75          Pasuruan                        148.62
# 76          Sidoarjo                        125.69
# 77         Mojokerto                        111.03
# 78           Jombang                        115.48
# 79           Nganjuk                        113.63
# 80            Madiun                         74.07
# 81           Magetan                         62.65
# 82             Ngawi                        119.02
# 83        Bojonegoro                        153.40
# 84             Tuban                        178.05
# 85          Lamongan                        151.08
# 86            Gresik                        149.64
# 87         Bangkalan                        196.11
# 88           Sampang                        217.97
# 89         Pamekasan                        126.02
# 90           Sumenep                        206.20
# 91       kota Kediri                         21.15
# 92       Kota Blitar                         10.65
# 93       Kota Malang                         38.56
# 94  Kota Probolinggo                         16.16
# 95     Kota Pasuruan                         13.02
# 96    Kota Mojokerto                          7.88
# 97       Kota Madiun                          8.49
# 98     Kota Surabaya                        138.21
# 99         Kota Batu                          8.05
#
#     Presentase penduduk miskin    P1        P2  \
# 0                     7.730000  1.49  0.450000
# 1                     7.340000  0.93  0.190000
# 2                    10.550000  1.35  0.270000
# 3                     6.800000  0.90  0.210000
# 4                    10.420000  1.81  0.450000
# 5                    10.730000  1.42  0.280000
# 6                     7.720000  1.07  0.240000
# 7                    12.760000  2.14  0.530000
# 8                    12.010000  2.27  0.590000
# 9                    11.940000  1.55  0.360000
# 10                   10.140000  1.98  0.530000
# 11                   12.770000  1.72  0.480000
# 12                    9.750000  1.55  0.410000
# 13                    8.700000  1.19  0.250000
# 14                    8.440000  1.58  0.410000
# 15                   10.009495  0.74  0.180000
# 16                   10.820000  1.70  0.410000
# 17                    9.320000  1.24  0.260000
# 18                    7.100000  1.27  0.290000
# 19                    8.020000  1.27  0.380000
# 20                    4.250000  0.70  0.170000
# 21                    9.820000  1.34  0.300000
# 22                    4.430000  0.96  0.270000
# 23                    2.530000  0.42  0.100000
# 24                    5.110000  0.67  0.140000
# 25                   12.720000  2.34  0.650000
# 26                    6.730000  1.02  0.280000
# 27                   11.020000  1.47  0.330000
# 28                   12.840000  1.75  0.350000
# 29                   15.300000  2.08  0.480000
# 30                   15.200000  2.34  0.480000
# 31                   16.410000  3.41  1.020000
# 32                   11.530000  1.31  0.240000
# 33                   16.170000  3.18  0.860000
# 34                   11.090000  1.66  0.410000
# 35                    9.820000  1.13  0.200000
# 36                   12.330000  1.86  0.440000
# 37                    7.610000  0.87  0.140000
# 38                   10.990000  1.33  0.290000
# 39                    9.850000  1.64  0.370000
# 40                   12.940000  2.07  0.349192
# 41                   11.800000  1.95  0.450000
# 42                   11.530000  1.80  0.420000
# 43                   14.650000  2.41  0.590000
# 44                    9.330000  1.20  0.250000
# 45                    7.410000  0.90  0.190000
# 46                    6.880000  1.22  0.300000
# 47                   12.090000  1.68  0.350000
# 48                    7.270000  1.03  0.220000
# 49                    9.330000  1.06  0.190000
# 50                    9.480000  1.52  0.390000
# 51                    8.980000  1.26  0.290000
# 52                    9.670000  1.67  0.430000
# 53                   15.060000  2.43  0.570000
# 54                    7.900000  0.95  0.170000
# 55                   16.050000  2.73  0.660000
# 56                    7.100000  0.47  0.060000
# 57                    8.840000  1.07  0.270000
# 58                    4.730000  0.66  0.150000
# 59                    4.250000  0.56  0.110000
# 60                    7.000000  0.90  0.170000
# 61                    7.910000  1.15  0.280000
# 62                   13.800000  1.35  0.230000
# 63                    9.320000  0.99  0.160000
# 64                   10.960000  1.38  0.280000
# 65                    6.710000  0.66  0.090000
# 66                    8.710000  1.33  0.300000
# 67                   10.650000  1.67  0.410000
# 68                    9.550000  0.92  0.180000
# 69                    9.060000  1.34  0.310000
# 70                    9.390000  1.08  0.220000
# 71                    7.510000  1.18  0.250000
# 72                   13.470000  1.62  0.330000
# 73                   11.780000  1.34  0.270000
# 74                   17.120000  2.54  0.590000
# 75                    8.960000  1.29  0.290000
# 76                    5.360000  0.84  0.180000
# 77                    9.710000  1.37  0.290000
# 78                    9.040000  1.19  0.230000
# 79                   10.700000  1.48  0.310000
# 80                   10.790000  1.67  0.370000
# 81                    9.840000  1.55  0.340000
# 82                   14.150000  1.66  0.310000
# 83                   12.210000  1.90  0.400000
# 84                   15.020000  2.89  0.810000
# 85                   12.530000  2.13  0.530000
# 86                   11.060000  2.17  0.890000
# 87                   19.440000  3.02  0.730000
# 88                   21.610000  2.88  0.530000
# 89                   13.930000  2.05  0.410000
# 90                   18.760000  3.72  1.160000
# 91                    7.230000  1.42  0.410000
# 92                    7.370000  0.90  0.190000
# 93                    4.370000  1.00  0.340000
# 94                    6.650000  1.04  0.230000
# 95                    6.370000  0.93  0.220000
# 96                    5.980000  0.87  0.180000
# 97                    4.760000  0.40  0.060000
# 98                    4.270000  0.69  0.180000
# 99                    3.790000  0.64  0.160000
#
#     Garis kemiskinan (Rp/Kap/Bulan)  Cluster
# 0                      443787.00000        2
# 1                      357636.00000        0
# 2                      406829.00000        0
# 3                      398884.00000        0
# 4                      335134.00000        0
# 5                      347917.00000        0
# 6                      451347.89899        2
# 7                      371665.00000        0
# 8                      416914.00000        0
# 9                      483319.00000        2
# 10                     371665.00000        0
# 11                     499805.00000        2
# 12                     372308.00000        0
# 13                     403663.00000        0
# 14                     521158.00000        1
# 15                     579221.00000        1
# 16                     393956.00000        0
# 17                     411174.00000        0
# 18                     608949.00000        1
# 19                     594118.00000        1
# 20                     545675.00000        1
# 21                     485613.00000        2
# 22                     731392.00000        1
# 23                     744771.00000        1
# 24                     549450.00000        1
# 25                     498711.00000        2
# 26                     373510.00000        0
# 27                     384955.00000        0
# 28                     441520.00000        2
# 29                     407849.00000        0
# 30                     351333.00000        0
# 31                     416004.00000        0
# 32                     393731.00000        0
# 33                     399180.00000        0
# 34                     377497.00000        0
# 35                     383030.00000        0
# 36                     458872.00000        2
# 37                     434318.00000        2
# 38                     376763.00000        0
# 39                     424677.00000        2
# 40                     389265.00000        0
# 41                     428597.00000        2
# 42                     390478.00000        0
# 43                     441482.00000        2
# 44                     486855.00000        2
# 45                     482806.00000        2
# 46                     442618.00000        2
# 47                     471818.00000        2
# 48                     459151.00000        2
# 49                     354012.00000        0
# 50                     433864.00000        2
# 51                     341252.00000        0
# 52                     441765.00000        2
# 53                     429549.00000        2
# 54                     434638.00000        2
# 55                     472326.00000        2
# 56                     575130.00000        1
# 57                     538441.00000        1
# 58                     518815.00000        1
# 59                     589598.00000        1
# 60                     513243.00000        2
# 61                     565826.00000        1
# 62                     327758.00000        0
# 63                     362461.00000        0
# 64                     381448.00000        0
# 65                     391888.00000        0
# 66                     355511.00000        0
# 67                     353033.00000        0
# 68                     367579.00000        0
# 69                     352776.00000        0
# 70                     400961.00000        0
# 71                     414879.00000        0
# 72                     449760.00000        2
# 73                     356133.00000        0
# 74                     475713.00000        2
# 75                     394016.00000        0
# 76                     523213.00000        1
# 77                     445608.00000        2
# 78                     448830.00000        2
# 79                     474429.00000        2
# 80                     405127.00000        0
# 81                     396696.00000        0
# 82                     382301.00000        0
# 83                     403403.00000        0
# 84                     421287.00000        2
# 85                     446601.00000        2
# 86                     536544.00000        1
# 87                     458754.00000        2
# 88                     411661.00000        0
# 89                     392345.00000        0
# 90                     427882.00000        2
# 91                     537326.00000        1
# 92                     517363.00000        1
# 93                     609612.00000        1
# 94                     575195.00000        1
# 95                     486893.00000        2
# 96                     531804.00000        1
# 97                     551620.00000        1
# 98                     652540.00000        1
# 99                     564010.00000        1

# %% [markdown]
# # Visualisasi Hasil Clustering

# %% [markdown]
# Mengisi nilai NaN dengan nilai median untuk kolom tertentu

# %%
columns_to_fill = ['Jumlah penduduk miskin (000)', 'Presentase penduduk miskin']
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].median())

# %% [markdown]
# Standarisasi fitur

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Jumlah cluster yang diinginkan

# %%
n_clusters = 3

# %% [markdown]
# 5.1 Melakukan clustering dengan K-Means

# %% [markdown]
# Menambahkan kolom cluster ke data asli

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
clusters = kmeans.fit_predict(X_scaled)

df['Cluster'] = clusters

# %% [markdown]
# 5.2 Visualisasi hasil clustering

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Jumlah penduduk miskin (000)')
plt.ylabel('Presentase penduduk miskin')
plt.title(f'Clustering Data Penduduk Miskin (Jumlah Cluster = {n_clusters})')
plt.colorbar(label='Cluster')
plt.show()

# %%
print(df['Cluster'].value_counts())
# Out:
# 1    55
# 0    28
# 2    17
# Name: Cluster, dtype: int64

# %% [markdown]
# # Menghitung jarak data ke setiap pusat cluster

# %% [markdown]
#  Menyimpan nama kota dalam DataFrame

# %%
kota = df['Kabupaten/Kota']

# %% [markdown]
# Memilih fitur yang akan digunakan untuk clustering

# %%
X = df[['Jumlah penduduk miskin (000)', 'Presentase penduduk miskin']]

# %% [markdown]
# Menghitung jarak data ke setiap pusat cluster

# %%
distances = pairwise_distances(X_scaled, kmeans.cluster_centers_)

# %% [markdown]
# Membuat DataFrame dengan keterangan nama kota dan matriks jarak

# %%
distance_df = pd.DataFrame(distances, columns=[f'Cluster_{i+1}' for i in range(n_clusters)])
distance_df.insert(0, 'Kabupaten/Kota', kota)

# %% [markdown]
# Menampilkan DataFrame dengan keterangan

# %%
print("Matrix Jarak dengan Nama Kota:")
print(distance_df)
# Out:
# Matrix Jarak dengan Nama Kota:
#       Kabupaten/Kota  Cluster_1  Cluster_2  Cluster_3
# 0              Bogor   5.788511   4.472315   4.878837
# 1           Sukabumi   2.884941   1.551288   4.344169
# 2            Cianjur   3.338353   1.440881   3.316746
# 3            Bandung   3.198543   2.083545   4.445493
# 4              Garut   4.445131   2.159491   2.826480
# 5        Tasikmalaya   3.390874   1.030592   3.229262
# 6             Ciamis   1.406486   1.259612   4.054698
# 7           Kuningan   3.941467   1.706207   1.577102
# 8            Cirebon   4.570742   2.542225   1.680209
# 9         Majalengka   2.499913   1.082798   2.612776
# 10          Sumedang   3.474322   1.419430   2.193520
# 11         Indramayu   3.476078   1.969384   2.130566
# 12            Subang   3.059250   0.680530   2.780230
# 13        Purwakarta   2.000583   0.968761   3.833244
# 14          Karawang   2.499380   1.747734   3.068635
# 15            Bekasi   2.183584   2.570435   4.487825
# 16     Bandung Barat   3.251967   0.872401   2.412527
# 17       Pangandaran   1.993550   1.377659   3.900318
# 18        Kota Bogor   1.082484   2.701952   4.416838
# 19     Kota Sukabumi   1.341675   2.763597   4.264602
# 20      Kota Bandung   0.960168   2.745888   5.246894
# 21      Kota Cirebon   1.559875   1.680256   3.728853
# 22       Kota Bekasi   2.469592   4.277793   5.740815
# 23        Kota Depok   2.667953   5.048133   6.974070
# 24       Kota Cimahi   0.628712   3.009678   5.482775
# 25  Kota Tasikmalaya   3.729655   2.607688   1.634801
# 26       Kota Banjar   2.246054   2.030275   4.577314
# 27           Cilacap   3.163298   0.765820   2.869434
# 28          Banyumas   3.453974   1.447075   2.355107
# 29       Purbalingga   3.991709   1.894981   1.430380
# 30     Banjar negara   4.476035   2.197529   1.572759
# 31           Kebumen   6.778128   5.009422   2.115762
# 32         Purworejo   2.507608   0.923309   3.460258
# 33          Wonosobo   5.930552   4.148207   1.439940
# 34          Magelang   3.163385   0.703825   2.485470
# 35          Boyolali   2.338603   0.974111   3.883044
# 36            Klaten   3.016607   1.236024   1.974704
# 37         Sukoharjo   1.494677   1.739035   4.627297
# 38          Wonogiri   2.678047   0.620318   3.275988
# 39       Karanganyar   2.356802   0.783399   2.913976
# 40            Sragen   3.410711   1.267153   2.242657
# 41          Grobogan   3.272781   1.184506   1.880970
# 42             Blora   3.060953   0.972895   2.408213
# 43           Rembang   4.089145   2.455339   1.222309
# 44              Pati   1.511636   1.153537   3.660979
# 45             Kudus   0.896530   1.850711   4.527069
# 46            Jepara   1.564646   1.256874   3.909878
# 47             Demak   2.620315   1.025280   2.493677
# 48          Semarang   1.207766   1.521033   4.272686
# 49        Temanggung   2.534314   1.377292   4.187281
# 50            Kendal   2.211224   0.791964   2.989654
# 51            Batang   2.729910   1.248679   3.825660
# 52        Pekalongan   2.365011   1.028421   2.765555
# 53          Pemalang   4.521053   2.510129   0.721757
# 54             Tegal   1.664151   1.332576   4.284181
# 55            Brebes   5.551779   3.732806   1.571027
# 56     Kota Magelang   1.170958   3.393711   5.796982
# 57    Kota Surakarta   0.867230   2.106079   4.208957
# 58     Kota Salatiga   0.928037   3.006390   5.544132
# 59     Kota Semarang   1.032956   3.326653   5.742369
# 60   Kota Pekalongan   0.680667   2.436147   4.901492
# 61        Kota Tegal   0.877368   2.570271   4.484940
# 62           Pacitan   3.483087   1.635582   3.544989
# 63          Ponorogo   2.451758   1.403676   4.287586
# 64        Trenggalek   2.578404   0.884413   3.375773
# 65       Tulungagung   2.030623   2.121523   5.101334
# 66            Blitar   2.652161   0.883333   3.602754
# 67            Kediri   3.442183   0.948821   2.602968
# 68            Malang   3.487932   1.892481   4.194374
# 69          Lumajang   2.702418   0.907376   3.550833
# 70            Jember   3.054821   1.457371   3.823310
# 71        Banyuwangi   1.952049   0.954784   3.884806
# 72         Bondowoso   2.758361   1.154266   2.599082
# 73         Situbondo   2.919012   1.066152   3.413031
# 74       Probolinggo   4.880584   3.120134   0.925001
# 75          Pasuruan   2.480706   0.491335   3.425983
# 76          Sidoarjo   1.015090   2.274589   4.828011
# 77         Mojokerto   1.950535   0.634208   3.304146
# 78           Jombang   1.719880   0.902517   3.728127
# 79           Nganjuk   2.020092   0.891029   3.044660
# 80            Madiun   2.623530   0.933656   2.859887
# 81           Magetan   2.441080   0.992778   3.238602
# 82             Ngawi   3.358269   1.195486   2.618592
# 83        Bojonegoro   3.300360   0.994270   2.085350
# 84             Tuban   5.453377   3.619026   0.767286
# 85          Lamongan   3.540573   1.704136   1.401494
# 86            Gresik   4.405626   3.487074   2.147583
# 87         Bangkalan   5.975595   4.193335   1.347171
# 88           Sampang   6.114495   4.119096   2.032507
# 89         Pamekasan   3.643438   1.468158   1.890651
# 90           Sumenep   7.769515   6.052851   3.093629
# 91       kota Kediri   1.448670   2.371648   3.995086
# 92       Kota Blitar   0.769142   2.488386   4.869606
# 93       Kota Malang   1.154418   3.265948   5.107081
# 94  Kota Probolinggo   0.648745   2.847571   4.913415
# 95     Kota Pasuruan   0.954578   2.350723   4.830689
# 96    Kota Mojokerto   0.667686   2.776927   5.158938
# 97       Kota Madiun   1.252826   3.514480   6.073557
# 98     Kota Surabaya   1.728253   3.637838   5.641940
# 99         Kota Batu   1.018758   3.420683   5.806628

# %% [markdown]
# # Menghitung jarak antara setiap data dengan pusat cluster terdekat

# %%
distances = kmeans.transform(X_scaled)  # Menggunakan transform untuk menghitung jarak

# %% [markdown]
# Membuat DataFrame dengan keterangan nama kota dan jarak ke pusat cluster terdekat

# %%
distance_df = pd.DataFrame(distances, columns=[f'Jarak ke Cluster {i+1}' for i in range(n_clusters)])
distance_df.insert(0, 'Kabupaten/Kota', df['Kabupaten/Kota'])

# %% [markdown]
# Menampilkan DataFrame dengan jarak ke pusat cluster terdekat

# %%
print("Jarak ke Pusat Cluster Terdekat:")
print(distance_df)
# Out:
# Jarak ke Pusat Cluster Terdekat:
#       Kabupaten/Kota  Jarak ke Cluster 1  Jarak ke Cluster 2  \
# 0              Bogor            5.788511            4.472315
# 1           Sukabumi            2.884941            1.551288
# 2            Cianjur            3.338353            1.440881
# 3            Bandung            3.198543            2.083545
# 4              Garut            4.445131            2.159491
# 5        Tasikmalaya            3.390874            1.030592
# 6             Ciamis            1.406486            1.259612
# 7           Kuningan            3.941467            1.706207
# 8            Cirebon            4.570742            2.542225
# 9         Majalengka            2.499913            1.082798
# 10          Sumedang            3.474322            1.419430
# 11         Indramayu            3.476078            1.969384
# 12            Subang            3.059250            0.680530
# 13        Purwakarta            2.000583            0.968761
# 14          Karawang            2.499380            1.747734
# 15            Bekasi            2.183584            2.570435
# 16     Bandung Barat            3.251967            0.872401
# 17       Pangandaran            1.993550            1.377659
# 18        Kota Bogor            1.082484            2.701952
# 19     Kota Sukabumi            1.341675            2.763597
# 20      Kota Bandung            0.960168            2.745888
# 21      Kota Cirebon            1.559875            1.680256
# 22       Kota Bekasi            2.469592            4.277793
# 23        Kota Depok            2.667953            5.048133
# 24       Kota Cimahi            0.628712            3.009678
# 25  Kota Tasikmalaya            3.729655            2.607688
# 26       Kota Banjar            2.246054            2.030275
# 27           Cilacap            3.163298            0.765820
# 28          Banyumas            3.453974            1.447075
# 29       Purbalingga            3.991709            1.894981
# 30     Banjar negara            4.476035            2.197529
# 31           Kebumen            6.778128            5.009422
# 32         Purworejo            2.507608            0.923309
# 33          Wonosobo            5.930552            4.148207
# 34          Magelang            3.163385            0.703825
# 35          Boyolali            2.338603            0.974111
# 36            Klaten            3.016607            1.236024
# 37         Sukoharjo            1.494677            1.739035
# 38          Wonogiri            2.678047            0.620318
# 39       Karanganyar            2.356802            0.783399
# 40            Sragen            3.410711            1.267153
# 41          Grobogan            3.272781            1.184506
# 42             Blora            3.060953            0.972895
# 43           Rembang            4.089145            2.455339
# 44              Pati            1.511636            1.153537
# 45             Kudus            0.896530            1.850711
# 46            Jepara            1.564646            1.256874
# 47             Demak            2.620315            1.025280
# 48          Semarang            1.207766            1.521033
# 49        Temanggung            2.534314            1.377292
# 50            Kendal            2.211224            0.791964
# 51            Batang            2.729910            1.248679
# 52        Pekalongan            2.365011            1.028421
# 53          Pemalang            4.521053            2.510129
# 54             Tegal            1.664151            1.332576
# 55            Brebes            5.551779            3.732806
# 56     Kota Magelang            1.170958            3.393711
# 57    Kota Surakarta            0.867230            2.106079
# 58     Kota Salatiga            0.928037            3.006390
# 59     Kota Semarang            1.032956            3.326653
# 60   Kota Pekalongan            0.680667            2.436147
# 61        Kota Tegal            0.877368            2.570271
# 62           Pacitan            3.483087            1.635582
# 63          Ponorogo            2.451758            1.403676
# 64        Trenggalek            2.578404            0.884413
# 65       Tulungagung            2.030623            2.121523
# 66            Blitar            2.652161            0.883333
# 67            Kediri            3.442183            0.948821
# 68            Malang            3.487932            1.892481
# 69          Lumajang            2.702418            0.907376
# 70            Jember            3.054821            1.457371
# 71        Banyuwangi            1.952049            0.954784
# 72         Bondowoso            2.758361            1.154266
# 73         Situbondo            2.919012            1.066152
# 74       Probolinggo            4.880584            3.120134
# 75          Pasuruan            2.480706            0.491335
# 76          Sidoarjo            1.015090            2.274589
# 77         Mojokerto            1.950535            0.634208
# 78           Jombang            1.719880            0.902517
# 79           Nganjuk            2.020092            0.891029
# 80            Madiun            2.623530            0.933656
# 81           Magetan            2.441080            0.992778
# 82             Ngawi            3.358269            1.195486
# 83        Bojonegoro            3.300360            0.994270
# 84             Tuban            5.453377            3.619026
# 85          Lamongan            3.540573            1.704136
# 86            Gresik            4.405626            3.487074
# 87         Bangkalan            5.975595            4.193335
# 88           Sampang            6.114495            4.119096
# 89         Pamekasan            3.643438            1.468158
# 90           Sumenep            7.769515            6.052851
# 91       kota Kediri            1.448670            2.371648
# 92       Kota Blitar            0.769142            2.488386
# 93       Kota Malang            1.154418            3.265948
# 94  Kota Probolinggo            0.648745            2.847571
# 95     Kota Pasuruan            0.954578            2.350723
# 96    Kota Mojokerto            0.667686            2.776927
# 97       Kota Madiun            1.252826            3.514480
# 98     Kota Surabaya            1.728253            3.637838
# 99         Kota Batu            1.018758            3.420683
#
#     Jarak ke Cluster 3
# 0             4.878837
# 1             4.344169
# 2             3.316746
# 3             4.445493
# 4             2.826480
# 5             3.229262
# 6             4.054698
# 7             1.577102
# 8             1.680209
# 9             2.612776
# 10            2.193520
# 11            2.130566
# 12            2.780230
# 13            3.833244
# 14            3.068635
# 15            4.487825
# 16            2.412527
# 17            3.900318
# 18            4.416838
# 19            4.264602
# 20            5.246894
# 21            3.728853
# 22            5.740815
# 23            6.974070
# 24            5.482775
# 25            1.634801
# 26            4.577314
# 27            2.869434
# 28            2.355107
# 29            1.430380
# 30            1.572759
# 31            2.115762
# 32            3.460258
# 33            1.439940
# 34            2.485470
# 35            3.883044
# 36            1.974704
# 37            4.627297
# 38            3.275988
# 39            2.913976
# 40            2.242657
# 41            1.880970
# 42            2.408213
# 43            1.222309
# 44            3.660979
# 45            4.527069
# 46            3.909878
# 47            2.493677
# 48            4.272686
# 49            4.187281
# 50            2.989654
# 51            3.825660
# 52            2.765555
# 53            0.721757
# 54            4.284181
# 55            1.571027
# 56            5.796982
# 57            4.208957
# 58            5.544132
# 59            5.742369
# 60            4.901492
# 61            4.484940
# 62            3.544989
# 63            4.287586
# 64            3.375773
# 65            5.101334
# 66            3.602754
# 67            2.602968
# 68            4.194374
# 69            3.550833
# 70            3.823310
# 71            3.884806
# 72            2.599082
# 73            3.413031
# 74            0.925001
# 75            3.425983
# 76            4.828011
# 77            3.304146
# 78            3.728127
# 79            3.044660
# 80            2.859887
# 81            3.238602
# 82            2.618592
# 83            2.085350
# 84            0.767286
# 85            1.401494
# 86            2.147583
# 87            1.347171
# 88            2.032507
# 89            1.890651
# 90            3.093629
# 91            3.995086
# 92            4.869606
# 93            5.107081
# 94            4.913415
# 95            4.830689
# 96            5.158938
# 97            6.073557
# 98            5.641940
# 99            5.806628
